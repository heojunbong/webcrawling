# %%
import pandas as pd

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "5mg3oysqm3WUPqW92feX"
client_secret = "0eBC52qwnH"
encText = urllib.parse.quote("강남역")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=100" # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 18 Aug 2023 02:27:36 +0900",
# 	"total":2118765,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"<b>강남역<\/b>치과 밝은 얼굴을 바라면",
# 			"link":"https:\/\/blog.naver.com\/vineyardk\/223186071982",
# 			"description":"그러다보니 지금 저희는 최신식의 디지털 장비를 보유하고 있고 이를 사용하여 강남치과에서 오차를 줄이는 방법을 사용할 수 있어요. <b>강남역<\/b>치과는 이런 것들로 출혈에 대해 고민을 낮출 수 있었고, 시간이... ",
# 			"bloggername":"자기치아살리기 삼성플란트치과의원",
# 			"bloggerlink":"blog.naver.com\/vineyardk",
# 			"postdate":"20230817"
# 		},
# 		{
# 			"title":"군침 도는 <b>강남역<\/b> 고기집",
# 			"link":"https:\/\/blog.naver.com\/anjigo\/223143175765",
# 			"description":"이날 갔다온 강남랭겹은 <b>강남역<\/b>에서 도보로 3분 정도 떨어진 거리에 위치해있었어요. 심플하면서 커다란 간판 모습이 멀리서부터 눈에 띄어서 초행길임에도 단번에 찾아갔죠. 매장 근처에 있는 유료주차장을... ",
# 			"bloggername":"Bravo, my all♩",
# 			"bloggerlink":"blog.naver.com\/anjigo",
# 			"postdate":"20230701"
# 		},
# 		{
# 			"title":"자꾸 기억나는 <b>강남역<\/b> 고기집 곱창고",
# 			"link":"https:\/\/blog.naver.com\/06131010\/223173851134",
# ...

# %%
#### API 호출한 후에 필요한 데이터 뽑기

import requests
from urllib.parse import urlparse

keyword = "강남역"
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword
result = requests.get(urlparse(url).geturl(),
          headers={"X-Naver-Client-Id":"5mg3oysqm3WUPqW92feX",
                   "X-Naver-Client-Secret":"0eBC52qwnH"})

json_obj = result.json()
print(json_obj['lastBuildDate'])
print(json_obj['total'])
print(json_obj['start'])
print(json_obj['display'])
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.15) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# Fri, 18 Aug 2023 03:16:47 +0900
# 2118629
# 1
# 10

# %%
json_obj
# Out:
# {'lastBuildDate': 'Fri, 18 Aug 2023 03:16:47 +0900',
#  'total': 2118629,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '<b>강남역</b>치과 빠른 진료를 본다면',
#    'link': 'https://blog.naver.com/vineyardk/223186071982',
#    'description': '그러다보니 지금 저희는 최신식의 디지털 장비를 보유하고 있고 이를 사용하여 강남치과에서 오차를 줄이는 방법을 사용할 수 있어요. <b>강남역</b>치과는 이런 것들로 출혈에 대해 고민을 낮출 수 있었고, 시간이... ',
#    'bloggername': '자기치아살리기 삼성플란트치과의원',
#    'bloggerlink': 'blog.naver.com/vineyardk',
#    'postdate': '20230817'},
#   {'title': '군침 도는 <b>강남역</b> 고기집',
#    'link': 'https://blog.naver.com/anjigo/223143175765',
#    'description': '이날 갔다온 강남랭겹은 <b>강남역</b>에서 도보로 3분 정도 떨어진 거리에 위치해있었어요. 심플하면서 커다란 간판 모습이 멀리서부터 눈에 띄어서 초행길임에도 단번에 찾아갔죠. 매장 근처에 있는 유료주차장을... ',
#    'bloggername': 'Bravo, my all♩',
#    'bloggerlink': 'blog.naver.com/anjigo',
#    'postdate': '20230701'},
#   {'title': '자꾸 기억나는 <b>강남역</b> 고기집 곱창고',
#    'link': 'https://blog.naver.com/06131010/223173851134',
# ...

# %%
### 검색 결과 출력하기

import requests
from urllib.parse import urlparse

keyword = "강남역"
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword
result = requests.get(urlparse(url).geturl(),
          headers={"X-Naver-Client-Id":"5mg3oysqm3WUPqW92feX",
                   "X-Naver-Client-Secret":"0eBC52qwnH"})

json_obj = result.json()
print(json_obj['items'])
# Out:
# [{'title': '<b>강남역</b>치과 빠른 진료를 본다면', 'link': 'https://blog.naver.com/vineyardk/223186071982', 'description': '그러다보니 지금 저희는 최신식의 디지털 장비를 보유하고 있고 이를 사용하여 강남치과에서 오차를 줄이는 방법을 사용할 수 있어요. <b>강남역</b>치과는 이런 것들로 출혈에 대해 고민을 낮출 수 있었고, 시간이... ', 'bloggername': '자기치아살리기 삼성플란트치과의원', 'bloggerlink': 'blog.naver.com/vineyardk', 'postdate': '20230817'}, {'title': '군침 도는 <b>강남역</b> 고기집', 'link': 'https://blog.naver.com/anjigo/223143175765', 'description': '이날 갔다온 강남랭겹은 <b>강남역</b>에서 도보로 3분 정도 떨어진 거리에 위치해있었어요. 심플하면서 커다란 간판 모습이 멀리서부터 눈에 띄어서 초행길임에도 단번에 찾아갔죠. 매장 근처에 있는 유료주차장을... ', 'bloggername': 'Bravo, my all♩', 'bloggerlink': 'blog.naver.com/anjigo', 'postdate': '20230701'}, {'title': '자꾸 기억나는 <b>강남역</b> 고기집 곱창고', 'link': 'https://blog.naver.com/06131010/223173851134', 'description': '이렇듯 모듬 구이와 전골, 반찬까지 흠잡을 곳 없이 완벽했던 <b>강남역</b> 고기집이라 앞으로도 자주 방문하게 될 것 같아요~ 주소: 서울 강남구 강남대로96길 11 번호: 0507-1386-0001 시간: 화~일11:30 - 01:00/월 11:30-23:00... ', 'bloggername': '오늘도 감사해요♡', 'bloggerlink': 'blog.naver.com/06131010
# ...

# %%
### 반복문으로 결과 출력하기

for item in json_obj['items']:
    print(item)
# Out:
# {'title': '<b>강남역</b>치과 빠른 진료를 본다면', 'link': 'https://blog.naver.com/vineyardk/223186071982', 'description': '그러다보니 지금 저희는 최신식의 디지털 장비를 보유하고 있고 이를 사용하여 강남치과에서 오차를 줄이는 방법을 사용할 수 있어요. <b>강남역</b>치과는 이런 것들로 출혈에 대해 고민을 낮출 수 있었고, 시간이... ', 'bloggername': '자기치아살리기 삼성플란트치과의원', 'bloggerlink': 'blog.naver.com/vineyardk', 'postdate': '20230817'}
# {'title': '군침 도는 <b>강남역</b> 고기집', 'link': 'https://blog.naver.com/anjigo/223143175765', 'description': '이날 갔다온 강남랭겹은 <b>강남역</b>에서 도보로 3분 정도 떨어진 거리에 위치해있었어요. 심플하면서 커다란 간판 모습이 멀리서부터 눈에 띄어서 초행길임에도 단번에 찾아갔죠. 매장 근처에 있는 유료주차장을... ', 'bloggername': 'Bravo, my all♩', 'bloggerlink': 'blog.naver.com/anjigo', 'postdate': '20230701'}
# ...

# %%
### 특정 속성값만 뽑아내기

for item in json_obj['items']:
    print(item['title'])
# Out:
# <b>강남역</b>치과 빠른 진료를 본다면
# 군침 도는 <b>강남역</b> 고기집
# 자꾸 기억나는 <b>강남역</b> 고기집 곱창고
# 역대급인 <b>강남역</b> 삼겹살
# 지금도 생각나는 <b>강남역</b> 고기집 봉우화로
# <b>강남역</b> 사진관 포토위크에서 인생 증명사진 건짐!
# 선택했던 <b>강남역</b> 회식장소
# <b>강남역</b> 데이트 맛집 위트앤미트 미국식 샌드위치 핫플
# <b>강남역</b> 파스타 그랑끼오로제 라자냐 맛집
# 가성비에 반한 <b>강남역</b> 삼겹살

# %%
#### <b>, </b> 없애기

for item in json_obj['items']:
    print(item['title'].replace("<b>","").replace("</b>",""))
# Out:
# 강남역치과 빠른 진료를 본다면
# 군침 도는 강남역 고기집
# 자꾸 기억나는 강남역 고기집 곱창고
# 역대급인 강남역 삼겹살
# 지금도 생각나는 강남역 고기집 봉우화로
# 강남역 사진관 포토위크에서 인생 증명사진 건짐!
# 선택했던 강남역 회식장소
# 강남역 데이트 맛집 위트앤미트 미국식 샌드위치 핫플
# 강남역 파스타 그랑끼오로제 라자냐 맛집
# 가성비에 반한 강남역 삼겹살

# %%
### 링크와 함께 출력하기

for item in json_obj['items']:
    print(item['title'].replace("<b>","").replace("</b>",""),
          item['link'])
# Out:
# 강남역치과 빠른 진료를 본다면 https://blog.naver.com/vineyardk/223186071982
# 군침 도는 강남역 고기집 https://blog.naver.com/anjigo/223143175765
# 자꾸 기억나는 강남역 고기집 곱창고 https://blog.naver.com/06131010/223173851134
# 역대급인 강남역 삼겹살 https://blog.naver.com/instyle02/223166935751
# 지금도 생각나는 강남역 고기집 봉우화로 https://blog.naver.com/eaenvy77/223157102810
# 강남역 사진관 포토위크에서 인생 증명사진 건짐! https://blog.naver.com/popinjay66/223177057653
# 선택했던 강남역 회식장소 https://blog.naver.com/nyjhg/223174865192
# 강남역 데이트 맛집 위트앤미트 미국식 샌드위치 핫플 https://blog.naver.com/kizaki56/223166373063
# 강남역 파스타 그랑끼오로제 라자냐 맛집 https://blog.naver.com/baisehua/223124377167
# 가성비에 반한 강남역 삼겹살 https://blog.naver.com/jung4553/223168608990

# %%
### 검색결과의 갯수 출력하기

import requests
from urllib.parse import urlparse

keyword = "강남역"
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword
result = requests.get(urlparse(url).geturl(),
          headers={"X-Naver-Client-Id":"5mg3oysqm3WUPqW92feX",
                   "X-Naver-Client-Secret":"0eBC52qwnH"})

json_obj = result.json()
print(json_obj['display'])
print(json_obj['start'])
print(len(json_obj['items']))
# Out:
# 10
# 1
# 10

# %%
#### 함수로 묶기
#### 함수를 통해서 검색결과를 10개에서 100개로 늘리기

import requests
from urllib.parse import urlparse

def get_api_result(keyword, display):
    url = "https://openapi.naver.com/v1/search/blog?query=" + keyword + "&display=" + str(display)
    result = requests.get(urlparse(url).geturl(),
          headers={"X-Naver-Client-Id":"5mg3oysqm3WUPqW92feX",
                   "X-Naver-Client-Secret":"0eBC52qwnH"})
    return result.json()

keyword = "강남역"
json_obj = get_api_result(keyword, 100)

print(json_obj['display'])
print(json_obj['start'])
print(len(json_obj['items']))
# Out:
# 100
# 1
# 100

# %%
import requests
from urllib.parse import urlparse

def get_api_result(keyword, display, start):
    url = "https://openapi.naver.com/v1/search/blog?query=" + keyword \
          + "&display=" + str(display) \
          + "&start=" + str(start)
    result = requests.get(urlparse(url).geturl(),
          headers={"X-Naver-Client-Id":"5mg3oysqm3WUPqW92feX",
                   "X-Naver-Client-Secret":"0eBC52qwnH"})
    return result.json()

keyword = "강남역"
json_obj = get_api_result(keyword, 100, 1)

print("display:", json_obj['display'])
print("start:", json_obj['start'])
print("items count:", len(json_obj['items']))
# Out:
# display: 100
# start: 1
# items count: 100

# %%
for item in json_obj['items']:
    print(item)
# Out:
# {'title': '<b>강남역</b>치과 빠른 진료를 본다면', 'link': 'https://blog.naver.com/vineyardk/223186071982', 'description': '그러다보니 지금 저희는 최신식의 디지털 장비를 보유하고 있고 이를 사용하여 강남치과에서 오차를 줄이는 방법을 사용할 수 있어요. <b>강남역</b>치과는 이런 것들로 출혈에 대해 고민을 낮출 수 있었고, 시간이... ', 'bloggername': '자기치아살리기 삼성플란트치과의원', 'bloggerlink': 'blog.naver.com/vineyardk', 'postdate': '20230817'}
# {'title': '군침 도는 <b>강남역</b> 고기집', 'link': 'https://blog.naver.com/anjigo/223143175765', 'description': '이날 갔다온 강남랭겹은 <b>강남역</b>에서 도보로 3분 정도 떨어진 거리에 위치해있었어요. 심플하면서 커다란 간판 모습이 멀리서부터 눈에 띄어서 초행길임에도 단번에 찾아갔죠. 매장 근처에 있는 유료주차장을... ', 'bloggername': 'Bravo, my all♩', 'bloggerlink': 'blog.naver.com/anjigo', 'postdate': '20230701'}
# ...

# %%
#### 검색 결과 페이징하기

import requests
from urllib.parse import urlparse

def get_api_result(keyword, display, start):
    url = "https://openapi.naver.com/v1/search/blog?query=" + keyword \
          + "&display=" + str(display) \
          + "&start=" + str(start)
    result = requests.get(urlparse(url).geturl(),
          headers={"X-Naver-Client-Id":"5mg3oysqm3WUPqW92feX",
                   "X-Naver-Client-Secret":"0eBC52qwnH"})
    return result.json()

def call_and_print(keyword, page):
    json_obj = get_api_result(keyword, 100, page)
    for item in json_obj['items']:
        print(item)

keyword = "강남역"
call_and_print(keyword, 1)
call_and_print(keyword, 101)
call_and_print(keyword, 201)
call_and_print(keyword, 301)
call_and_print(keyword, 401)
# Out:
# {'title': '<b>강남역</b>치과 빠른 진료를 본다면', 'link': 'https://blog.naver.com/vineyardk/223186071982', 'description': '그러다보니 지금 저희는 최신식의 디지털 장비를 보유하고 있고 이를 사용하여 강남치과에서 오차를 줄이는 방법을 사용할 수 있어요. <b>강남역</b>치과는 이런 것들로 출혈에 대해 고민을 낮출 수 있었고, 시간이... ', 'bloggername': '자기치아살리기 삼성플란트치과의원', 'bloggerlink': 'blog.naver.com/vineyardk', 'postdate': '20230817'}
# {'title': '군침 도는 <b>강남역</b> 고기집', 'link': 'https://blog.naver.com/anjigo/223143175765', 'description': '이날 갔다온 강남랭겹은 <b>강남역</b>에서 도보로 3분 정도 떨어진 거리에 위치해있었어요. 심플하면서 커다란 간판 모습이 멀리서부터 눈에 띄어서 초행길임에도 단번에 찾아갔죠. 매장 근처에 있는 유료주차장을... ', 'bloggername': 'Bravo, my all♩', 'bloggerlink': 'blog.naver.com/anjigo', 'postdate': '20230701'}
# ...
